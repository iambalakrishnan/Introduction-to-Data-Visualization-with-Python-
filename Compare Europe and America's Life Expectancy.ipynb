# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Load the datafile
data = pd.read_csv('countries.csv')

# %%
#preview
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
#select 1997 data
data_1997 = data[data['year'] == 1997]

# %%
data_1997
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 9            Afghanistan      Asia  1997          41.763    22227415
# 21               Albania    Europe  1997          72.950     3428038
# 33               Algeria    Africa  1997          69.152    29072015
# 45                Angola    Africa  1997          40.963     9875024
# 57             Argentina  Americas  1997          73.275    36203463
# ...                  ...       ...   ...             ...         ...
# 1653             Vietnam      Asia  1997          70.672    76048996
# 1665  West Bank and Gaza      Asia  1997          71.096     2826046
# 1677         Yemen, Rep.      Asia  1997          58.020    15826497
# 1689              Zambia    Africa  1997          40.238     9417789
# 1701            Zimbabwe    Africa  1997          46.809    11404948
#
#       gdpPerCapita
# 9       635.341351
# 21     3193.054604
# 33     4797.295051
# 45     2277.140884
# 57    10967.281950
# ...

# %%
#selecting America's 1997 data
americas_1997 = data_1997[data_1997['continent'] == 'Americas']

# %%
americas_1997
# Out:
#                   country continent  year  lifeExpectancy  population  \
# 57              Argentina  Americas  1997          73.275    36203463
# 141               Bolivia  Americas  1997          62.050     7693188
# 177                Brazil  Americas  1997          69.388   168546719
# 249                Canada  Americas  1997          78.610    30305843
# 285                 Chile  Americas  1997          75.816    14599929
# 309              Colombia  Americas  1997          70.313    37657830
# 357            Costa Rica  Americas  1997          77.260     3518107
# 393                  Cuba  Americas  1997          76.151    10983007
# 441    Dominican Republic  Americas  1997          69.957     7992357
# 453               Ecuador  Americas  1997          72.312    11911819
# 477           El Salvador  Americas  1997          69.535     5783439
# 609             Guatemala  Americas  1997          66.322     9803875
# ...

# %%
#Selecting Europe 1997 data
europe_1997 = data_1997[data_1997['continent'] == 'Europe']

# %%
europe_1997
# Out:
#                      country continent  year  lifeExpectancy  population  \
# 21                   Albania    Europe  1997          72.950     3428038
# 81                   Austria    Europe  1997          77.510     8069876
# 117                  Belgium    Europe  1997          77.530    10199787
# 153   Bosnia and Herzegovina    Europe  1997          73.244     3607000
# 189                 Bulgaria    Europe  1997          70.320     8066057
# 381                  Croatia    Europe  1997          73.680     4444595
# 405           Czech Republic    Europe  1997          74.010    10300707
# 417                  Denmark    Europe  1997          76.110     5283663
# 525                  Finland    Europe  1997          77.130     5134406
# 537                   France    Europe  1997          78.640    58623428
# 573                  Germany    Europe  1997          77.340    82011073
# 597                   Greece    Europe  1997          77.869    10502372
# ...

# %%
#Find the ledngth of America's 1997 data 
print(len(set(americas_1997['country'])))
# Out:
# 25

# %%
#Find the ledngth of Europe's 1997 data 
print(len(set(europe_1997['country'])))
# Out:
# 30

# %%
#Finding mean and median for America's 1997 data

print("Mean of life expectancy in America : ", americas_1997['lifeExpectancy'].mean())

print("Median of life expectancy in America : ", americas_1997['lifeExpectancy'].median())
# Out:
# Mean of life expectancy in America :  71.15047999999999
# Median of life expectancy in America :  72.146

# %%
#Finding mean and median for Europe's 1997 data

print("Mean of life expectancy in europe : ", europe_1997['lifeExpectancy'].mean())

print("Median of life expectancy in europe : ", europe_1997['lifeExpectancy'].median())
# Out:
# Mean of life expectancy in europe :  75.50516666666667
# Median of life expectancy in europe :  76.116

# %%
#Plotting

plt.subplot(211)
bins = 20
plt.title('Distribution of Life Expectancy')
plt.hist(americas_1997['lifeExpectancy'], bins, range = (55, 85), edgecolor = 'black')
plt.ylabel('Americas')

plt.subplot(212)
plt.hist(europe_1997['lifeExpectancy'], bins, range = (55, 85), edgecolor = 'black')
plt.ylabel('Europe')
plt.show()

# %%
# finding outliers which lies below 65
americas_1997[americas_1997['lifeExpectancy'] < 65]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 141  Bolivia  Americas  1997          62.050     7693188   3326.143191
# 645    Haiti  Americas  1997          56.671     6913545   1341.726931
